# %% [markdown]
# ### EduSpend CP#30: Global Higher-Education Cost Analytics & Planning
# EDA Provided by Cursor

# %% [markdown]
# Findings:
# - No missing values or duplicate rows
# - 907 entries, 12 columns
# - 71 countries, UK, Australia, US and Canada represent over 36% of the entries
# - Highs of Tuition, Rent & Insurance in USA, Cost of Living in Switzerland, Visa Fees in UK (Denmark has unusual spread)
# - 556 cities, led by Singapore
# - 622 universities, led by University of Washington
# - 3 degree levels led by Masters
# - 92 programs, with computer science a distant first with 34%
# - Linear relationship between Rent, Living Cost, and Tuition
# - Increasing # of outliers within Rent, Living Cost Index, Insurance, Visa Fee and Exchange Rate
# - Total Cost of Attendance is Tuition (*total program*) + Visa Fee + (Insurance * years) + (Rent * 12 * years)
# - TCA average of dataset is $52K, led by PhD $69K, USA $128K, Stanford $193, Machine Learning $158K

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kaggle
import os
import warnings
from scipy import stats

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# Download the dataset
kaggle.api.dataset_download_files('adilshamim8/cost-of-international-education', path='../data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/adilshamim8/cost-of-international-education

# %%
df = pd.read_csv('../data/International_Education_Costs.csv')

# %%
# Basic information
print("Dataset Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
print("\nUnique Values:\n", df.nunique())
print("\nDuplicated Values:\n", df.duplicated().sum())
print("\nBasic Statistics:\n", df.describe())
# Out:
# Dataset Shape: (907, 12)
#
# Columns: ['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years', 'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD', 'Insurance_USD', 'Exchange_Rate']
#
# Data Types:
#  Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object
#
# Missing Values:
#  Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object
#
# Missing Values:
#  Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64
#
# Unique Values:
#  Country               71
# City                 556
# University           622
# Program               92
# Level                  3
# Duration_Years         7
# Tuition_USD          274
# Living_Cost_Index    225
# Rent_USD              67
# Visa_Fee_USD          30
# Insurance_USD         20
# Exchange_Rate         65
# dtype: int64
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64
#
# Unique Values:
#  Country               71
# City                 556
# University           622
# Program               92
# Level                  3
# Duration_Years         7
# Tuition_USD          274
# Living_Cost_Index    225
# Rent_USD              67
# Visa_Fee_USD          30
# Insurance_USD         20
# Exchange_Rate         65
# dtype: int64
#
# Duplicated Values:
#  0
#
# Duplicated Values:
#  0
#
# Basic Statistics:
#
# Basic Statistics:
#         Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# 75%      240.000000     800.000000       7.150000
# max      490.000000    1500.000000   42150.000000
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# 75%      240.000000     800.000000       7.150000
# max      490.000000    1500.000000   42150.000000

# %% [markdown]
# no duplicate or missing values, but outliers on the max line, zero tuition, exchange rate standard deviation

# %% [markdown]
# Data Quality Assessment

# %%
# Check for outliers using Interquartile Range (IQR) method
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers

# Apply to numerical columns
numerical_columns = df.select_dtypes(include=[np.number]).columns
for col in numerical_columns:
    outliers = detect_outliers(df, col)
    print(f"\nOutliers in {col}:", len(outliers))
# Out:
# Outliers in Duration_Years: 0
#
# Outliers in Tuition_USD: 0
#
# Outliers in Living_Cost_Index: 20
#
# Outliers in Rent_USD: 3
#
# Outliers in Visa_Fee_USD: 93
#
# Outliers in Insurance_USD: 78
#
# Outliers in Exchange_Rate: 169

# %% [markdown]
# Each country should have one exchange rate

# %%
# Find countries with multiple unique exchange rates and show those rates with their counts
multi_rate_countries = df.groupby('Country')['Exchange_Rate'].nunique()
multi_rate_countries = multi_rate_countries[multi_rate_countries > 1].index

# For each country, get a sorted list of (rate, count) tuples
print("\nCountries with multiple exchange rates and their counts:")
print("-" * 50)
for country in multi_rate_countries:
    rates_counts = df[df['Country'] == country]['Exchange_Rate'].value_counts().sort_index()
    rates_list = [(rate, count) for rate, count in rates_counts.items()]
    print(f"{country}: {rates_list}")
# Out:
# Countries with multiple exchange rates and their counts:
# --------------------------------------------------
# Argentina: [(275.0, 5), (821.5, 1)]
# China: [(7.15, 10), (7.18, 2)]
# Denmark: [(0.15, 3), (6.92, 2), (7.45, 10)]
# India: [(82.75, 7), (83.2, 1)]
# Indonesia: [(15600.0, 7), (15640.0, 1)]
# Malaysia: [(4.65, 9), (4.72, 1)]
# Mexico: [(17.05, 8), (17.2, 1)]
# New Zealand: [(1.64, 1), (1.65, 8)]
# Poland: [(4.02, 1), (4.1, 7)]
# Russia: [(92.8, 1), (95.5, 8)]
# Singapore: [(1.34, 12), (1.35, 6)]
# South Korea: [(1300.0, 20), (1320.5, 3)]
# Thailand: [(35.2, 1), (35.25, 7)]
# Turkey: [(28.5, 8), (30.5, 1)]

# %%
# Replace exchange rates for countries with multiple rates with their most frequent value
for country in multi_rate_countries:
    most_freq_rate = df[df['Country'] == country]['Exchange_Rate'].mode()[0]
    df.loc[df['Country'] == country, 'Exchange_Rate'] = most_freq_rate
print("Exchange rates replaced with most frequent value for countries with multiple rates.")
# Out:
# Exchange rates replaced with most frequent value for countries with multiple rates.

# %% [markdown]
# Update cities with weighted average cost of living index

# %%
# Find (Country, City) pairs with multiple unique cost of living rates and show those rates with their counts
multi_rate_city_country = df.groupby(['Country', 'City'])['Living_Cost_Index'].nunique()
multi_rate_city_country = multi_rate_city_country[multi_rate_city_country > 1].index

# For each (Country, City), get a sorted list of (rate, count) tuples
print("\n(Country, City) pairs with multiple living cost rates and their counts:")
print("-" * 60)
for country, city in multi_rate_city_country:
    rates_counts = df[(df['Country'] == country) & (df['City'] == city)]['Living_Cost_Index'].value_counts().sort_index()
    rates_list = [(rate, count) for rate, count in rates_counts.items()]
    print(f"({country}, {city}): {rates_list}")
# Out:
# (Country, City) pairs with multiple living cost rates and their counts:
# ------------------------------------------------------------
# (Argentina, Buenos Aires): [(42.5, 1), (42.6, 1)]
# (Australia, Adelaide): [(64.5, 1), (67.5, 3), (68.5, 1)]
# (Australia, Armidale): [(63.8, 3), (64.8, 1)]
# (Australia, Brisbane): [(68.7, 1), (69.2, 6)]
# (Australia, Canberra): [(68.9, 6), (69.8, 1), (70.2, 1)]
# (Australia, Gold Coast): [(65.4, 1), (67.5, 1), (68.5, 3)]
# (Australia, Hobart): [(62.1, 1), (64.5, 3), (65.4, 1)]
# (Australia, Melbourne): [(71.2, 1), (72.4, 1), (72.8, 9)]
# (Australia, Newcastle): [(63.2, 1), (66.2, 3), (66.8, 1)]
# (Australia, Perth): [(67.2, 1), (68.2, 3), (69.8, 1)]
# (Australia, Sydney): [(72.8, 1), (74.5, 9), (75.6, 1)]
# (Australia, Townsville): [(65.2, 3), (65.8, 1)]
# (Australia, Wollongong): [(63.4, 1), (65.8, 3), (67.2, 1)]
# (Austria, Vienna): [(67.4, 1), (78.5, 1)]
# (Belgium, Brussels): [(68.9, 1), (75.4, 1)]
# (Brazil, Sao Paulo): [(48.5, 1), (55.8, 1)]
# (Canada, Calgary): [(62.8, 2), (65.4, 1), (69.2, 1)]
# (Canada, Edmonton): [(61.9, 2), (64.3, 1), (67.8, 1)]
# (Canada, Halifax): [(61.2, 2), (63.4, 1), (64.5, 1)]
# (Canada, Hamilton): [(64.2, 2), (68.5, 1)]
# (Canada, Montreal): [(65.8, 4), (68.9, 1)]
# (Canada, Ottawa): [(63.5, 2), (67.8, 1), (68.5, 1)]
# (Canada, Quebec City): [(58.5, 2), (62.1, 1), (63.8, 1)]
# (Canada, Regina): [(57.5, 2), (61.8, 1)]
# (Canada, Saskatoon): [(58.2, 2), (62.8, 1)]
# (Canada, Sherbrooke): [(56.8, 2), (61.5, 1)]
# (Canada, St. John's): [(57.9, 2), (63.2, 1)]
# (Canada, Toronto): [(72.5, 1), (73.5, 2), (73.8, 1)]
# (Canada, Victoria): [(64.5, 1), (64.8, 2), (69.2, 1)]
# (Canada, Waterloo): [(62.4, 2), (69.8, 1)]
# (Canada, Winnipeg): [(59.8, 2), (61.2, 1), (62.5, 1)]
# (China, Beijing): [(51.2, 2), (52.3, 1)]
# (Denmark, Aalborg): [(69.8, 1), (71.5, 1), (75.1, 1)]
# (Denmark, Aarhus): [(76.5, 1), (77.4, 1)]
# (Denmark, Copenhagen): [(73.4, 1), (82.1, 1), (83.2, 1)]
# (Egypt, Cairo): [(31.8, 1), (38.4, 1)]
# (Finland, Helsinki): [(70.2, 1), (79.4, 1)]
# (France, Bordeaux): [(67.8, 1), (72.1, 2)]
# (France, Grenoble): [(66.4, 1), (71.5, 1)]
# (France, Lille): [(65.5, 1), (69.8, 2)]
# (France, Lyon): [(68.5, 1), (75.6, 2)]
# (France, Nice): [(69.2, 1), (76.5, 2)]
# (France, Paris): [(74.6, 2), (84.3, 2)]
# (France, Strasbourg): [(66.2, 1), (70.2, 2)]
# (France, Toulouse): [(65.8, 1), (71.2, 1), (72.1, 1)]
# (Germany, Aachen): [(66.4, 1), (68.9, 2)]
# (Germany, Berlin): [(65.2, 1), (68.9, 2)]
# (Germany, Darmstadt): [(66.8, 1), (66.9, 1)]
# (Germany, Dresden): [(65.4, 2), (65.8, 1)]
# (Germany, Hamburg): [(69.8, 2), (71.2, 1)]
# (Germany, Heidelberg): [(67.8, 1), (68.4, 1)]
# (Germany, Jena): [(63.8, 1), (65.4, 1)]
# (Germany, Karlsruhe): [(67.8, 1), (67.9, 1)]
# (Germany, Munich): [(70.5, 1), (71.5, 2)]
# (Germany, Stuttgart): [(68.5, 1), (68.7, 2)]
# (Greece, Athens): [(54.8, 1), (65.8, 2)]
# (India, Bangalore): [(45.2, 1), (45.6, 1)]
# (Ireland, Dublin): [(72.9, 1), (83.6, 1)]
# (Ireland, Galway): [(68.5, 1), (72.3, 1)]
# (Italy, Milan): [(63.8, 1), (73.2, 2)]
# (Malaysia, Kuala Lumpur): [(48.2, 1), (55.4, 1)]
# (Mexico, Mexico City): [(44.6, 1), (52.4, 1)]
# (Netherlands, Amsterdam): [(73.2, 1), (73.5, 1), (81.2, 1)]
# (Netherlands, Delft): [(71.8, 1), (76.5, 1)]
# (Netherlands, Eindhoven): [(69.8, 1), (72.3, 1)]
# (Netherlands, Groningen): [(66.8, 1), (71.2, 1)]
# (Netherlands, Rotterdam): [(71.5, 1), (77.8, 1)]
# (Netherlands, Tilburg): [(65.8, 1), (70.5, 1)]
# (Netherlands, Utrecht): [(70.2, 1), (75.4, 1)]
# (Netherlands, Wageningen): [(65.2, 1), (69.8, 1)]
# (New Zealand, Auckland): [(69.8, 1), (79.5, 2)]
# (Norway, Oslo): [(75.6, 1), (83.2, 1)]
# (Poland, Warsaw): [(51.2, 1), (54.8, 1)]
# (Portugal, Lisbon): [(58.4, 1), (65.8, 1)]
# (Russia, Moscow): [(51.2, 1), (62.3, 1)]
# (Saudi Arabia, Riyadh): [(52.4, 1), (72.5, 1)]
# (Singapore, Singapore): [(81.1, 11), (81.5, 1), (83.8, 6)]
# (South Korea, Busan): [(62.4, 1), (73.2, 2)]
# (South Korea, Daejeon): [(65.4, 1), (75.4, 3)]
# (South Korea, Seoul): [(68.7, 1), (85.1, 5)]
# (Spain, Barcelona): [(62.4, 1), (73.6, 2)]
# (Sweden, Lund): [(69.5, 1), (73.4, 1)]
# (Sweden, Stockholm): [(71.8, 1), (78.4, 1)]
# (Switzerland, Basel): [(87.5, 1), (88.6, 1), (114.3, 1)]
# (Switzerland, Bern): [(85.4, 1), (110.4, 1)]
# (Switzerland, Fribourg): [(83.8, 1), (107.8, 1)]
# (Switzerland, Geneva): [(90.5, 1), (116.5, 1)]
# (Switzerland, Lausanne): [(89.8, 1), (119.8, 1)]
# (Switzerland, Lugano): [(84.5, 1), (108.9, 1)]
# (Switzerland, St. Gallen): [(86.2, 1), (112.1, 1)]
# (Switzerland, Zurich): [(91.5, 1), (122.4, 1)]
# (Thailand, Bangkok): [(46.5, 1), (51.4, 1)]
# (Turkey, Istanbul): [(42.8, 1), (51.2, 1)]
# (UK, Birmingham): [(65.4, 1), (66.8, 1), (71.8, 1)]
# (UK, Bristol): [(68.9, 3), (69.8, 1), (74.8, 1)]
# (UK, Cambridge): [(71.2, 1), (71.5, 1), (75.2, 1), (78.5, 1)]
# (UK, Cardiff): [(64.2, 1), (64.5, 1), (69.8, 1)]
# (UK, Durham): [(63.4, 1), (71.6, 1)]
# (UK, Edinburgh): [(67.8, 3), (75.4, 1)]
# (UK, Glasgow): [(64.5, 2), (67.5, 1), (73.2, 1)]
# (UK, Leeds): [(63.2, 3), (65.8, 1), (71.2, 1)]
# (UK, London): [(75.3, 3), (75.8, 1), (76.2, 1), (83.2, 3)]
# (UK, Manchester): [(65.4, 3), (68.4, 1), (72.1, 1)]
# (UK, Newcastle): [(64.6, 1), (70.1, 1)]
# (UK, Nottingham): [(61.2, 2), (64.8, 1), (70.8, 1)]
# (UK, Oxford): [(71.5, 2), (74.5, 1), (77.8, 1)]
# (UK, Sheffield): [(62.3, 1), (64.5, 1), (70.5, 1)]
# (UK, Southampton): [(65.9, 1), (72.4, 1)]
# (UK, Warwick): [(67.2, 1), (71.5, 1)]
# (USA, Ann Arbor): [(72.5, 1), (75.4, 1)]
# (USA, Atlanta): [(71.2, 2), (71.5, 1), (76.8, 1)]
# (USA, Austin): [(68.9, 3), (72.4, 1), (72.8, 1)]
# (USA, Berkeley): [(83.2, 2), (84.2, 1), (91.5, 1)]
# (USA, Boston): [(82.1, 4), (83.2, 1)]
# (USA, Chicago): [(78.9, 1), (84.1, 2)]
# (USA, Davis): [(73.2, 1), (73.5, 1)]
# (USA, Los Angeles): [(79.8, 2), (88.7, 1)]
# (USA, Madison): [(69.5, 1), (71.2, 1)]
# (USA, Minneapolis): [(72.3, 1), (72.8, 1)]
# (USA, Philadelphia): [(76.8, 1), (82.4, 1)]
# (USA, Pittsburgh): [(65.4, 2), (72.4, 1)]
# (USA, Raleigh): [(67.8, 1), (71.8, 1)]
# (USA, San Diego): [(75.6, 2), (79.5, 1)]
# (USA, Seattle): [(77.8, 4), (83.4, 1), (85.6, 1)]
# (USA, Stanford): [(84.3, 2), (89.5, 1), (95.2, 1)]
# (USA, Tempe): [(70.2, 1), (72.5, 1)]
#
# (France, Nice): [(69.2, 1), (76.5, 2)]
# (France, Paris): [(74.6, 2), (84.3, 2)]
# (France, Strasbourg): [(66.2, 1), (70.2, 2)]
# (France, Toulouse): [(65.8, 1), (71.2, 1), (72.1, 1)]
# (Germany, Aachen): [(66.4, 1), (68.9, 2)]
# (Germany, Berlin): [(65.2, 1), (68.9, 2)]
# (Germany, Darmstadt): [(66.8, 1), (66.9, 1)]
# (Germany, Dresden): [(65.4, 2), (65.8, 1)]
# (Germany, Hamburg): [(69.8, 2), (71.2, 1)]
# (Germany, Heidelberg): [(67.8, 1), (68.4, 1)]
# (Germany, Jena): [(63.8, 1), (65.4, 1)]
# (Germany, Karlsruhe): [(67.8, 1), (67.9, 1)]
# (Germany, Munich): [(70.5, 1), (71.5, 2)]
# (Germany, Stuttgart): [(68.5, 1), (68.7, 2)]
# (Greece, Athens): [(54.8, 1), (65.8, 2)]
# (India, Bangalore): [(45.2, 1), (45.6, 1)]
# (Ireland, Dublin): [(72.9, 1), (83.6, 1)]
# (Ireland, Galway): [(68.5, 1), (72.3, 1)]
# (Italy, Milan): [(63.8, 1), (73.2, 2)]
# (Malaysia, Kuala Lumpur): [(48.2, 1), (55.4, 1)]
# (Mexico, Mexico City): [(44.6, 1), (52.4, 1)]
# (Netherlands, Amsterdam): [(73.2, 1), (73.5, 1), (81.2, 1)]
# (Netherlands, Delft): [(71.8, 1), (76.5, 1)]
# (Netherlands, Eindhoven): [(69.8, 1), (72.3, 1)]
# (Netherlands, Groningen): [(66.8, 1), (71.2, 1)]
# (Netherlands, Rotterdam): [(71.5, 1), (77.8, 1)]
# (Netherlands, Tilburg): [(65.8, 1), (70.5, 1)]
# (Netherlands, Utrecht): [(70.2, 1), (75.4, 1)]
# (Netherlands, Wageningen): [(65.2, 1), (69.8, 1)]
# (New Zealand, Auckland): [(69.8, 1), (79.5, 2)]
# (Norway, Oslo): [(75.6, 1), (83.2, 1)]
# (Poland, Warsaw): [(51.2, 1), (54.8, 1)]
# (Portugal, Lisbon): [(58.4, 1), (65.8, 1)]
# (Russia, Moscow): [(51.2, 1), (62.3, 1)]
# (Saudi Arabia, Riyadh): [(52.4, 1), (72.5, 1)]
# (Singapore, Singapore): [(81.1, 11), (81.5, 1), (83.8, 6)]
# (South Korea, Busan): [(62.4, 1), (73.2, 2)]
# (South Korea, Daejeon): [(65.4, 1), (75.4, 3)]
# (South Korea, Seoul): [(68.7, 1), (85.1, 5)]
# (Spain, Barcelona): [(62.4, 1), (73.6, 2)]
# (Sweden, Lund): [(69.5, 1), (73.4, 1)]
# (Sweden, Stockholm): [(71.8, 1), (78.4, 1)]
# (Switzerland, Basel): [(87.5, 1), (88.6, 1), (114.3, 1)]
# (Switzerland, Bern): [(85.4, 1), (110.4, 1)]
# (Switzerland, Fribourg): [(83.8, 1), (107.8, 1)]
# (Switzerland, Geneva): [(90.5, 1), (116.5, 1)]
# (Switzerland, Lausanne): [(89.8, 1), (119.8, 1)]
# (Switzerland, Lugano): [(84.5, 1), (108.9, 1)]
# (Switzerland, St. Gallen): [(86.2, 1), (112.1, 1)]
# (Switzerland, Zurich): [(91.5, 1), (122.4, 1)]
# (Thailand, Bangkok): [(46.5, 1), (51.4, 1)]
# (Turkey, Istanbul): [(42.8, 1), (51.2, 1)]
# (UK, Birmingham): [(65.4, 1), (66.8, 1), (71.8, 1)]
# (UK, Bristol): [(68.9, 3), (69.8, 1), (74.8, 1)]
# (UK, Cambridge): [(71.2, 1), (71.5, 1), (75.2, 1), (78.5, 1)]
# (UK, Cardiff): [(64.2, 1), (64.5, 1), (69.8, 1)]
# (UK, Durham): [(63.4, 1), (71.6, 1)]
# (UK, Edinburgh): [(67.8, 3), (75.4, 1)]
# (UK, Glasgow): [(64.5, 2), (67.5, 1), (73.2, 1)]
# (UK, Leeds): [(63.2, 3), (65.8, 1), (71.2, 1)]
# (UK, London): [(75.3, 3), (75.8, 1), (76.2, 1), (83.2, 3)]
# (UK, Manchester): [(65.4, 3), (68.4, 1), (72.1, 1)]
# (UK, Newcastle): [(64.6, 1), (70.1, 1)]
# (UK, Nottingham): [(61.2, 2), (64.8, 1), (70.8, 1)]
# (UK, Oxford): [(71.5, 2), (74.5, 1), (77.8, 1)]
# (UK, Sheffield): [(62.3, 1), (64.5, 1), (70.5, 1)]
# (UK, Southampton): [(65.9, 1), (72.4, 1)]
# (UK, Warwick): [(67.2, 1), (71.5, 1)]
# (USA, Ann Arbor): [(72.5, 1), (75.4, 1)]
# (USA, Atlanta): [(71.2, 2), (71.5, 1), (76.8, 1)]
# (USA, Austin): [(68.9, 3), (72.4, 1), (72.8, 1)]
# (USA, Berkeley): [(83.2, 2), (84.2, 1), (91.5, 1)]
# (USA, Boston): [(82.1, 4), (83.2, 1)]
# (USA, Chicago): [(78.9, 1), (84.1, 2)]
# (USA, Davis): [(73.2, 1), (73.5, 1)]
# (USA, Los Angeles): [(79.8, 2), (88.7, 1)]
# (USA, Madison): [(69.5, 1), (71.2, 1)]
# (USA, Minneapolis): [(72.3, 1), (72.8, 1)]
# (USA, Philadelphia): [(76.8, 1), (82.4, 1)]
# (USA, Pittsburgh): [(65.4, 2), (72.4, 1)]
# (USA, Raleigh): [(67.8, 1), (71.8, 1)]
# (USA, San Diego): [(75.6, 2), (79.5, 1)]
# (USA, Seattle): [(77.8, 4), (83.4, 1), (85.6, 1)]
# (USA, Stanford): [(84.3, 2), (89.5, 1), (95.2, 1)]
# (USA, Tempe): [(70.2, 1), (72.5, 1)]

# %%
# Replace Living Cost Index for each (Country, City) pair with its weighted average
for country, city in multi_rate_city_country:
    subset = df[(df['Country'] == country) & (df['City'] == city)]
    # Calculate weighted average: value_counts gives weights
    value_counts = subset['Living_Cost_Index'].value_counts()
    values = value_counts.index.to_numpy()
    weights = value_counts.values
    weighted_avg = (values * weights).sum() / weights.sum()
    df.loc[(df['Country'] == country) & (df['City'] == city), 'Living_Cost_Index'] = weighted_avg
print("Living Cost Index replaced with weighted average for (Country, City) pairs with multiple rates.")
# Out:
# Living Cost Index replaced with weighted average for (Country, City) pairs with multiple rates.

# %% [markdown]
# Univariate Analysis

# %%
# Distribution of numerical variables
plt.figure(figsize=(15, 15))
for i, col in enumerate(numerical_columns[:-1], 1):  # Exclude the last column (Exchange Rate)
    plt.subplot(4, 2, i)
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Distribution of Exchange Rate using boxplot due to outliers
plt.figure(figsize=(5, 3))
sns.boxplot(data=df, y='Exchange_Rate')
plt.title('Exchange Rate Distribution')
plt.show()

# %%
# Distribution of Exchange Rate excluding outliers
plt.figure(figsize=(10, 6))

# Filter data to remove extreme values (keep values within 3 standard deviations)
filtered_data = df[df['Exchange_Rate'].between(
    df['Exchange_Rate'].mean() - 3*df['Exchange_Rate'].std(),
    df['Exchange_Rate'].mean() + 3*df['Exchange_Rate'].std()
)]

# Create the histogram with specific bin size
sns.histplot(data=filtered_data, x='Exchange_Rate', kde=True, bins=50)

# Add a title and labels
plt.title('Distribution of Exchange Rate (Filtered)')
plt.xlabel('Exchange Rate')
plt.ylabel('Count')

# Print some statistics about the filtered data
print("Filtered Data Statistics:")
print(filtered_data['Exchange_Rate'].describe().round(2))

plt.show()
# Out:
# Filtered Data Statistics:
# count     883.00
# mean       76.94
# std       384.24
# min         0.31
# 25%         0.92
# 50%         1.35
# 75%         4.65
# max      3950.00
# Name: Exchange_Rate, dtype: float64

# %%
# Categorical variables analysis
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"\nValue counts for {col}:")
    value_counts = df[col].value_counts().head(30)
    print(df[col].value_counts())
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df, x=col, order=value_counts.index)
    plt.xticks(rotation=90, fontsize=8)
    plt.title(f'Distribution of first 30 in {col}')
    plt.show()
# Out:
# Value counts for Country:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Czech Republic     1
# Hong Kong          1
# Israel             1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64
# Value counts for City:
# City
# Singapore      18
# Sydney         11
# Melbourne      11
# London         10
# Canberra        8
#                ..
# Penang          1
# Santa Tecla     1
# Andijan         1
# Tabriz          1
# Subotica        1
# Name: count, Length: 556, dtype: int64
# Value counts for University:
# University
# University of Washington           6
# Stanford University                5
# Australian National University     5
# University of Tasmania             5
# University of Western Australia    5
#                                   ..
# USM                                1
# Universidad Politecnica            1
# Imperial College                   1
# ITCA-FEPADE                        1
# Andijan State University           1
# Name: count, Length: 622, dtype: int64
# Value counts for Program:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64
# Value counts for Level:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
# Histograms for numerical columns
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# Box plots for numerical columns
for col in df.select_dtypes(include=np.number).columns:
    sns.boxplot(x=df[col])
    plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
# Correlation analysis
plt.figure(figsize=(6,4))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# strong correlations between Rent & Living Cost & Insurance, as well as Rent & Tuition

# %%
# Scatter plots for key numerical variables
sns.pairplot(df[numerical_columns])
plt.show()

# %%
# Box plots for categorical vs numerical variables
for cat_col in categorical_columns:
    print(f"\nValue counts for {cat_col}:")
    value_counts = df[cat_col].value_counts().head(30)
    print(df[cat_col].value_counts())
    for num_col in numerical_columns:
        plt.figure(figsize=(12, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col, order=value_counts.index)
        plt.xticks(rotation=90, fontsize=8)
        plt.title(f'Top 30 {cat_col} vs {num_col}')
        plt.show()
# Out:
# Value counts for Country:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Czech Republic     1
# Hong Kong          1
# Israel             1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64
# Value counts for City:
# City
# Singapore      18
# Sydney         11
# Melbourne      11
# London         10
# Canberra        8
#                ..
# Penang          1
# Santa Tecla     1
# Andijan         1
# Tabriz          1
# Subotica        1
# Name: count, Length: 556, dtype: int64
# Value counts for University:
# University
# University of Washington           6
# Stanford University                5
# Australian National University     5
# University of Tasmania             5
# University of Western Australia    5
#                                   ..
# USM                                1
# Universidad Politecnica            1
# Imperial College                   1
# ITCA-FEPADE                        1
# Andijan State University           1
# Name: count, Length: 622, dtype: int64
# Value counts for Program:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64
# Value counts for Level:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %% [markdown]
# Feature Engineering (TCA = Total Cost of Attendance)

# %%
# tuition + visa + (rent × months x years) + (insurance × years)
# tuition is total program, visa is one time, rent is monthly, insurance is yearly
df['TCA'] = df['Tuition_USD'] + df['Visa_Fee_USD'] + (df['Rent_USD'] * 12 * df['Duration_Years']) + (df['Insurance_USD'] * df['Duration_Years'])

# %% [markdown]
# Key Insights and Summary

# %%
# Summary statistics by groups
for cat_col in categorical_columns:
    print(f"\nSummary statistics by {cat_col}:")
    print(df.groupby(cat_col)[numerical_columns].agg(['mean', 'std', 'min', 'max']).round(1))

# Calculate key metrics
print("\nKey Metrics:")
print("Average TCA by country:", df.groupby('Country')['TCA'].mean().round(1).sort_values(ascending=False))
print("TCA range by program type:", df.groupby('Program')['TCA'].agg(['min', 'max', 'mean']).round(1))
# Out:
# Summary statistics by Country:
#            Duration_Years                Tuition_USD                        \
#                      mean  std  min  max        mean     std    min    max
# Country
# Algeria               2.8  0.8  2.0  4.0      1100.0   158.1    900   1300
# Argentina             3.5  1.2  2.0  5.0         0.0     0.0      0      0
# Australia             3.0  0.8  2.0  4.0     34610.5  5231.0  25200  45800
# Austria               2.7  0.7  2.0  4.0      1500.0     0.0   1500   1500
# Bahrain               3.2  1.1  2.0  4.0      7600.0   961.8   6500   9000
# ...                   ...  ...  ...  ...         ...     ...    ...    ...
# USA                   3.4  1.2  2.0  5.0     47742.3  8454.1  26500  62000
# Ukraine               2.8  1.1  2.0  4.0      3520.0   192.4   3300   3800
# Uruguay               2.8  1.1  2.0  4.0      2700.0  3701.4      0   7000
# Uzbekistan            2.8  1.1  2.0  4.0      3620.0   389.9   3200   4200
# Vietnam               4.0  NaN  4.0  4.0      3200.0     NaN   3200   3200
#
#            Living_Cost_Index       ... Visa_Fee_USD      Insurance_USD         \
#                         mean  std  ...          min  max          mean    std
# Country                            ...
# Algeria                 35.7  2.0  ...           80   80         200.0    0.0
# Argentina               39.6  2.5  ...           90  150         283.3    8.2
# Australia               68.2  3.6  ...          450  450         650.0    0.0
# Austria                 71.1  1.5  ...          160  160         811.1  116.7
# Bahrain                 62.9  1.6  ...          130  130         600.0    0.0
# ...                      ...  ...  ...          ...  ...           ...    ...
# USA                     77.8  8.1  ...          160  160        1500.0    0.0
# Ukraine                 42.8  2.0  ...          120  120         300.0    0.0
# Uruguay                 48.9  2.2  ...           90   90         350.0    0.0
# Uzbekistan              40.4  2.7  ...          160  160         250.0    0.0
# Vietnam                 43.6  NaN  ...          120  120         250.0    NaN
#
#                        Exchange_Rate
#              min   max          mean  std      min      max
# Country
# Algeria      200   200         137.5  0.0    137.5    137.5
# Argentina    280   300         275.0  0.0    275.0    275.0
# Australia    650   650           1.5  0.0      1.5      1.5
# Austria      500   850           0.9  0.0      0.9      0.9
# Bahrain      600   600           0.4  0.0      0.4      0.4
# ...          ...   ...           ...  ...      ...      ...
# USA         1500  1500           1.0  0.0      1.0      1.0
# Ukraine      300   300          36.8  0.0     36.8     36.8
# Uruguay      350   350          39.5  0.0     39.5     39.5
# Uzbekistan   250   250       12300.0  0.0  12300.0  12300.0
# Vietnam      250   250       24450.0  NaN  24450.0  24450.0
#
# [71 rows x 28 columns]
#
# Summary statistics by City:
#           Duration_Years                Tuition_USD                        \
#                     mean  std  min  max        mean     std    min    max
# City
# Aachen               2.7  0.6  2.0  3.0       166.7   288.7      0    500
# Aalborg              2.7  0.6  2.0  3.0      2800.0  4849.7      0   8400
# Aarhus               2.0  0.0  2.0  2.0      4300.0  6081.1      0   8600
# Aberdeen             4.0  NaN  4.0  4.0     27700.0     NaN  27700  27700
# Abu Dhabi            2.0  NaN  2.0  2.0     27000.0     NaN  27000  27000
# ...                  ...  ...  ...  ...         ...     ...    ...    ...
# Zadar                4.0  NaN  4.0  4.0      3600.0     NaN   3600   3600
# Zagreb               4.0  NaN  4.0  4.0      4000.0     NaN   4000   4000
# Zaragoza             3.0  1.4  2.0  4.0      2900.0     0.0   2900   2900
# Zurich               2.0  0.0  2.0  2.0      1480.0    28.3   1460   1500
# Ås                   2.0  NaN  2.0  2.0         0.0     NaN      0      0
#
#           Living_Cost_Index       ... Visa_Fee_USD      Insurance_USD         \
#                        mean  std  ...          min  max          mean    std
# City                              ...
# Aachen                 68.1  0.0  ...           75  110         783.3  202.1
# Aalborg                72.1  0.0  ...          110  450         616.7  175.6
# Aarhus                 77.0  0.0  ...          110  450         700.0  141.4
# Aberdeen               69.5  NaN  ...          490  490         800.0    NaN
# Abu Dhabi              71.8  NaN  ...          270  270         750.0    NaN
# ...                     ...  ...  ...          ...  ...           ...    ...
# Zadar                  53.2  NaN  ...           80   80         400.0    NaN
# Zagreb                 58.9  NaN  ...           80   80         400.0    NaN
# Zaragoza               63.2  0.0  ...           80   80         750.0    0.0
# Zurich                107.0  0.0  ...           88  140        1200.0    0.0
# Ås                     70.5  NaN  ...          275  275         700.0    NaN
#
#                       Exchange_Rate
#             min   max          mean  std   min   max
# City
# Aachen      550   900           0.9  0.0   0.9   0.9
# Aalborg     450   800           7.4  0.0   7.4   7.4
# Aarhus      600   800           7.4  0.0   7.4   7.4
# Aberdeen    800   800           0.8  NaN   0.8   0.8
# Abu Dhabi   750   750           3.7  NaN   3.7   3.7
# ...         ...   ...           ...  ...   ...   ...
# Zadar       400   400           7.4  NaN   7.4   7.4
# Zagreb      400   400           7.4  NaN   7.4   7.4
# Zaragoza    750   750           0.9  0.0   0.9   0.9
# Zurich     1200  1200           0.9  0.0   0.9   0.9
# Ås          700   700          10.4  NaN  10.4  10.4
#
# [556 rows x 28 columns]
#
# Summary statistics by University:
#                               Duration_Years                Tuition_USD  \
#                                         mean  std  min  max        mean
# University
# ACK                                      2.0  NaN  2.0  2.0     13000.0
# AUT University                           2.0  NaN  2.0  2.0     29500.0
# Aalborg University                       2.7  0.6  2.0  3.0      2800.0
# Aalto University                         3.0  NaN  3.0  3.0         0.0
# Aarhus University                        2.0  0.0  2.0  2.0      2866.7
# ...                                      ...  ...  ...  ...         ...
# ZHAW                                     2.0  NaN  2.0  2.0      1460.0
# Zhejiang University                      3.0  NaN  3.0  3.0      7500.0
# École Normale Supérieure                 2.0  NaN  2.0  2.0      4200.0
# École Normale Supérieure Lyon            2.0  NaN  2.0  2.0      4800.0
# École Polytechnique                      2.0  NaN  2.0  2.0     15600.0
#
#                                                     Living_Cost_Index       \
#                                   std    min    max              mean  std
# University
# ACK                               NaN  13000  13000              64.5  NaN
# AUT University                    NaN  29500  29500              76.3  NaN
# Aalborg University             4849.7      0   8400              72.1  0.0
# Aalto University                  NaN      0      0              77.8  NaN
# Aarhus University              4965.2      0   8600              73.4  6.2
# ...                               ...    ...    ...               ...  ...
# ZHAW                              NaN   1460   1460              86.4  NaN
# Zhejiang University               NaN   7500   7500              45.3  NaN
# École Normale Supérieure          NaN   4200   4200              73.2  NaN
# École Normale Supérieure Lyon     NaN   4800   4800              73.2  NaN
# École Polytechnique               NaN  15600  15600              79.4  NaN
#
#                                ... Visa_Fee_USD      Insurance_USD         \
#                                ...          min  max          mean    std
# University                     ...
# ACK                            ...          140  140         700.0    NaN
# AUT University                 ...          330  330         600.0    NaN
# Aalborg University             ...          110  450         616.7  175.6
# Aalto University               ...          350  350         650.0    NaN
# Aarhus University              ...          110  450         733.3  115.5
# ...                            ...          ...  ...           ...    ...
# ZHAW                           ...           88   88        1200.0    NaN
# Zhejiang University            ...          140  140         400.0    NaN
# École Normale Supérieure       ...           99   99         850.0    NaN
# École Normale Supérieure Lyon  ...           99   99         650.0    NaN
# École Polytechnique            ...           99   99         650.0    NaN
#
#                                           Exchange_Rate
#                                 min   max          mean  std  min  max
# University
# ACK                             700   700           0.3  NaN  0.3  0.3
# AUT University                  600   600           1.6  NaN  1.6  1.6
# Aalborg University              450   800           7.4  0.0  7.4  7.4
# Aalto University                650   650           0.9  NaN  0.9  0.9
# Aarhus University               600   800           7.4  0.0  7.4  7.4
# ...                             ...   ...           ...  ...  ...  ...
# ZHAW                           1200  1200           0.9  NaN  0.9  0.9
# Zhejiang University             400   400           7.2  NaN  7.2  7.2
# École Normale Supérieure        850   850           0.9  NaN  0.9  0.9
# École Normale Supérieure Lyon   650   650           0.9  NaN  0.9  0.9
# École Polytechnique             650   650           0.9  NaN  0.9  0.9
#
# [622 rows x 28 columns]
#
# Summary statistics by Program:
#                         Duration_Years                Tuition_USD           \
#                                   mean  std  min  max        mean      std
# Program
# AI Engineering                     2.0  NaN  2.0  2.0      6100.0      NaN
# Aerospace Engineering              3.0  1.4  2.0  4.0     26150.0  36981.7
# Applied Mathematics                2.0  NaN  2.0  2.0      3900.0      NaN
# Architecture                       3.5  0.7  3.0  4.0      3150.0    495.0
# Artificial Intelligence            2.8  1.0  1.0  5.0     12895.5  16316.3
# ...                                ...  ...  ...  ...         ...      ...
# Software Systems                   2.7  1.2  2.0  4.0     10366.7  13306.1
# Sustainable Energy                 2.0  NaN  2.0  2.0         0.0      NaN
# Sustainable Technology             2.0  NaN  2.0  2.0         0.0      NaN
# Systems Engineering                2.0  NaN  2.0  2.0         0.0      NaN
# Technology & Innovation            2.0  NaN  2.0  2.0     33800.0      NaN
#
#                                       Living_Cost_Index        ...  \
#                            min    max              mean   std  ...
# Program                                                        ...
# AI Engineering            6100   6100              72.3   NaN  ...
# Aerospace Engineering        0  52300              71.3   3.8  ...
# Applied Mathematics       3900   3900              56.8   NaN  ...
# Architecture              2800   3500              66.0   5.5  ...
# Artificial Intelligence      0  58000              63.1  15.6  ...
# ...                        ...    ...               ...   ...  ...
# Software Systems           500  25500              65.2   6.7  ...
# Sustainable Energy           0      0              71.2   NaN  ...
# Sustainable Technology       0      0              75.1   NaN  ...
# Systems Engineering          0      0              66.7   NaN  ...
# Technology & Innovation  33800  33800              82.0   NaN  ...
#
#                         Visa_Fee_USD      Insurance_USD                    \
#                                  min  max          mean    std  min   max
# Program
# AI Engineering                    90   90         800.0    NaN  800   800
# Aerospace Engineering            110  160        1200.0  424.3  900  1500
# Applied Mathematics              120  120         350.0    NaN  350   350
# Architecture                     120  160         475.0   35.4  450   500
# Artificial Intelligence           60  485         650.2  310.4  200  1500
# ...                              ...  ...           ...    ...  ...   ...
# Software Systems                  75  235         750.0  180.3  550   900
# Sustainable Energy               120  120         750.0    NaN  750   750
# Sustainable Technology           110  110         400.0    NaN  400   400
# Systems Engineering              275  275         700.0    NaN  700   700
# Technology & Innovation           90   90         800.0    NaN  800   800
#
#                         Exchange_Rate
#                                  mean     std     min      max
# Program
# AI Engineering                 1300.0     NaN  1300.0   1300.0
# Aerospace Engineering             1.0     0.1     0.9      1.0
# Applied Mathematics              95.5     NaN    95.5     95.5
# Architecture                      0.9     0.0     0.9      0.9
# Artificial Intelligence        1126.9  6130.7     0.3  42150.0
# ...                               ...     ...     ...      ...
# Software Systems                434.1   749.9     0.9   1300.0
# Sustainable Energy               10.4     NaN    10.4     10.4
# Sustainable Technology           10.4     NaN    10.4     10.4
# Systems Engineering              10.4     NaN    10.4     10.4
# Technology & Innovation           1.3     NaN     1.3      1.3
#
# [92 rows x 28 columns]
#
# Summary statistics by Level:
#          Duration_Years                Tuition_USD                      \
#                    mean  std  min  max        mean      std min    max
# Level
# Bachelor            3.5  0.5  3.0  5.0     19792.7  15534.6   0  57000
# Master              2.0  0.2  1.0  3.0     14522.0  16642.4   0  62000
# PhD                 4.1  0.3  3.0  5.0     17129.6  17438.8   0  56000
#
#          Living_Cost_Index        ... Visa_Fee_USD      Insurance_USD         \
#                       mean   std  ...          min  max          mean    std
# Level                             ...
# Bachelor              64.6  12.4  ...           40  490         717.2  318.0
# Master                64.7  14.5  ...           40  485         691.2  309.7
# PhD                   63.2  14.4  ...           60  485         693.4  353.7
#
#                     Exchange_Rate
#           min   max          mean     std  min      max
# Level
# Bachelor  200  1500         496.6  3356.2  0.3  42150.0
# Master    200  1500         608.5  3518.8  0.3  42150.0
# PhD       200  1500         896.2  5137.8  0.3  42150.0
#
# [3 rows x 28 columns]
#
# Key Metrics:
# Average TCA by country: Country
# USA           127748.5
# Hong Kong      96520.0
# Singapore      89517.8
# Australia      85741.3
# Canada         73643.6
#                 ...
# Ghana          12548.0
# Uzbekistan     12496.0
# Bangladesh      9216.0
# Algeria         8532.0
# Tunisia         7773.3
# Name: TCA, Length: 71, dtype: float64
# TCA range by program type:                              min       max     mean
# Program
# AI Engineering           21710.0   21710.0  21710.0
# Aerospace Engineering    28310.0  144860.0  86585.0
# Applied Mathematics      21520.0   21520.0  21520.0
# Architecture             33770.0   50560.0  42165.0
# Artificial Intelligence   6660.0  163260.0  41540.7
# ...                          ...       ...      ...
# Software Systems         17275.0   72535.0  36600.0
# Sustainable Energy       24420.0   24420.0  24420.0
# Sustainable Technology   29710.0   29710.0  29710.0
# Systems Engineering      20875.0   20875.0  20875.0
# Technology & Innovation  71490.0   71490.0  71490.0
#
# [92 rows x 3 columns]
#            Duration_Years                Tuition_USD                        \
#                      mean  std  min  max        mean     std    min    max
# Country
# Algeria               2.8  0.8  2.0  4.0      1100.0   158.1    900   1300
# Argentina             3.5  1.2  2.0  5.0         0.0     0.0      0      0
# Australia             3.0  0.8  2.0  4.0     34610.5  5231.0  25200  45800
# Austria               2.7  0.7  2.0  4.0      1500.0     0.0   1500   1500
# Bahrain               3.2  1.1  2.0  4.0      7600.0   961.8   6500   9000
# ...                   ...  ...  ...  ...         ...     ...    ...    ...
# USA                   3.4  1.2  2.0  5.0     47742.3  8454.1  26500  62000
# Ukraine               2.8  1.1  2.0  4.0      3520.0   192.4   3300   3800
# Uruguay               2.8  1.1  2.0  4.0      2700.0  3701.4      0   7000
# Uzbekistan            2.8  1.1  2.0  4.0      3620.0   389.9   3200   4200
# Vietnam               4.0  NaN  4.0  4.0      3200.0     NaN   3200   3200
#
#            Living_Cost_Index       ... Visa_Fee_USD      Insurance_USD         \
#                         mean  std  ...          min  max          mean    std
# Country                            ...
# Algeria                 35.7  2.0  ...           80   80         200.0    0.0
# Argentina               39.6  2.5  ...           90  150         283.3    8.2
# Australia               68.2  3.6  ...          450  450         650.0    0.0
# Austria                 71.1  1.5  ...          160  160         811.1  116.7
# Bahrain                 62.9  1.6  ...          130  130         600.0    0.0
# ...                      ...  ...  ...          ...  ...           ...    ...
# USA                     77.8  8.1  ...          160  160        1500.0    0.0
# Ukraine                 42.8  2.0  ...          120  120         300.0    0.0
# Uruguay                 48.9  2.2  ...           90   90         350.0    0.0
# Uzbekistan              40.4  2.7  ...          160  160         250.0    0.0
# Vietnam                 43.6  NaN  ...          120  120         250.0    NaN
#
#                        Exchange_Rate
#              min   max          mean  std      min      max
# Country
# Algeria      200   200         137.5  0.0    137.5    137.5
# Argentina    280   300         275.0  0.0    275.0    275.0
# Australia    650   650           1.5  0.0      1.5      1.5
# Austria      500   850           0.9  0.0      0.9      0.9
# Bahrain      600   600           0.4  0.0      0.4      0.4
# ...          ...   ...           ...  ...      ...      ...
# USA         1500  1500           1.0  0.0      1.0      1.0
# Ukraine      300   300          36.8  0.0     36.8     36.8
# Uruguay      350   350          39.5  0.0     39.5     39.5
# Uzbekistan   250   250       12300.0  0.0  12300.0  12300.0
# Vietnam      250   250       24450.0  NaN  24450.0  24450.0
#
# [71 rows x 28 columns]
#
# Summary statistics by City:
#           Duration_Years                Tuition_USD                        \
#                     mean  std  min  max        mean     std    min    max
# City
# Aachen               2.7  0.6  2.0  3.0       166.7   288.7      0    500
# Aalborg              2.7  0.6  2.0  3.0      2800.0  4849.7      0   8400
# Aarhus               2.0  0.0  2.0  2.0      4300.0  6081.1      0   8600
# Aberdeen             4.0  NaN  4.0  4.0     27700.0     NaN  27700  27700
# Abu Dhabi            2.0  NaN  2.0  2.0     27000.0     NaN  27000  27000
# ...                  ...  ...  ...  ...         ...     ...    ...    ...
# Zadar                4.0  NaN  4.0  4.0      3600.0     NaN   3600   3600
# Zagreb               4.0  NaN  4.0  4.0      4000.0     NaN   4000   4000
# Zaragoza             3.0  1.4  2.0  4.0      2900.0     0.0   2900   2900
# Zurich               2.0  0.0  2.0  2.0      1480.0    28.3   1460   1500
# Ås                   2.0  NaN  2.0  2.0         0.0     NaN      0      0
#
#           Living_Cost_Index       ... Visa_Fee_USD      Insurance_USD         \
#                        mean  std  ...          min  max          mean    std
# City                              ...
# Aachen                 68.1  0.0  ...           75  110         783.3  202.1
# Aalborg                72.1  0.0  ...          110  450         616.7  175.6
# Aarhus                 77.0  0.0  ...          110  450         700.0  141.4
# Aberdeen               69.5  NaN  ...          490  490         800.0    NaN
# Abu Dhabi              71.8  NaN  ...          270  270         750.0    NaN
# ...                     ...  ...  ...          ...  ...           ...    ...
# Zadar                  53.2  NaN  ...           80   80         400.0    NaN
# Zagreb                 58.9  NaN  ...           80   80         400.0    NaN
# Zaragoza               63.2  0.0  ...           80   80         750.0    0.0
# Zurich                107.0  0.0  ...           88  140        1200.0    0.0
# Ås                     70.5  NaN  ...          275  275         700.0    NaN
#
#                       Exchange_Rate
#             min   max          mean  std   min   max
# City
# Aachen      550   900           0.9  0.0   0.9   0.9
# Aalborg     450   800           7.4  0.0   7.4   7.4
# Aarhus      600   800           7.4  0.0   7.4   7.4
# Aberdeen    800   800           0.8  NaN   0.8   0.8
# Abu Dhabi   750   750           3.7  NaN   3.7   3.7
# ...         ...   ...           ...  ...   ...   ...
# Zadar       400   400           7.4  NaN   7.4   7.4
# Zagreb      400   400           7.4  NaN   7.4   7.4
# Zaragoza    750   750           0.9  0.0   0.9   0.9
# Zurich     1200  1200           0.9  0.0   0.9   0.9
# Ås          700   700          10.4  NaN  10.4  10.4
#
# [556 rows x 28 columns]
#
# Summary statistics by University:
#                               Duration_Years                Tuition_USD  \
#                                         mean  std  min  max        mean
# University
# ACK                                      2.0  NaN  2.0  2.0     13000.0
# AUT University                           2.0  NaN  2.0  2.0     29500.0
# Aalborg University                       2.7  0.6  2.0  3.0      2800.0
# Aalto University                         3.0  NaN  3.0  3.0         0.0
# Aarhus University                        2.0  0.0  2.0  2.0      2866.7
# ...                                      ...  ...  ...  ...         ...
# ZHAW                                     2.0  NaN  2.0  2.0      1460.0
# Zhejiang University                      3.0  NaN  3.0  3.0      7500.0
# École Normale Supérieure                 2.0  NaN  2.0  2.0      4200.0
# École Normale Supérieure Lyon            2.0  NaN  2.0  2.0      4800.0
# École Polytechnique                      2.0  NaN  2.0  2.0     15600.0
#
#                                                     Living_Cost_Index       \
#                                   std    min    max              mean  std
# University
# ACK                               NaN  13000  13000              64.5  NaN
# AUT University                    NaN  29500  29500              76.3  NaN
# Aalborg University             4849.7      0   8400              72.1  0.0
# Aalto University                  NaN      0      0              77.8  NaN
# Aarhus University              4965.2      0   8600              73.4  6.2
# ...                               ...    ...    ...               ...  ...
# ZHAW                              NaN   1460   1460              86.4  NaN
# Zhejiang University               NaN   7500   7500              45.3  NaN
# École Normale Supérieure          NaN   4200   4200              73.2  NaN
# École Normale Supérieure Lyon     NaN   4800   4800              73.2  NaN
# École Polytechnique               NaN  15600  15600              79.4  NaN
#
#                                ... Visa_Fee_USD      Insurance_USD         \
#                                ...          min  max          mean    std
# University                     ...
# ACK                            ...          140  140         700.0    NaN
# AUT University                 ...          330  330         600.0    NaN
# Aalborg University             ...          110  450         616.7  175.6
# Aalto University               ...          350  350         650.0    NaN
# Aarhus University              ...          110  450         733.3  115.5
# ...                            ...          ...  ...           ...    ...
# ZHAW                           ...           88   88        1200.0    NaN
# Zhejiang University            ...          140  140         400.0    NaN
# École Normale Supérieure       ...           99   99         850.0    NaN
# École Normale Supérieure Lyon  ...           99   99         650.0    NaN
# École Polytechnique            ...           99   99         650.0    NaN
#
#                                           Exchange_Rate
#                                 min   max          mean  std  min  max
# University
# ACK                             700   700           0.3  NaN  0.3  0.3
# AUT University                  600   600           1.6  NaN  1.6  1.6
# Aalborg University              450   800           7.4  0.0  7.4  7.4
# Aalto University                650   650           0.9  NaN  0.9  0.9
# Aarhus University               600   800           7.4  0.0  7.4  7.4
# ...                             ...   ...           ...  ...  ...  ...
# ZHAW                           1200  1200           0.9  NaN  0.9  0.9
# Zhejiang University             400   400           7.2  NaN  7.2  7.2
# École Normale Supérieure        850   850           0.9  NaN  0.9  0.9
# École Normale Supérieure Lyon   650   650           0.9  NaN  0.9  0.9
# École Polytechnique             650   650           0.9  NaN  0.9  0.9
#
# [622 rows x 28 columns]
#
# Summary statistics by Program:
#                         Duration_Years                Tuition_USD           \
#                                   mean  std  min  max        mean      std
# Program
# AI Engineering                     2.0  NaN  2.0  2.0      6100.0      NaN
# Aerospace Engineering              3.0  1.4  2.0  4.0     26150.0  36981.7
# Applied Mathematics                2.0  NaN  2.0  2.0      3900.0      NaN
# Architecture                       3.5  0.7  3.0  4.0      3150.0    495.0
# Artificial Intelligence            2.8  1.0  1.0  5.0     12895.5  16316.3
# ...                                ...  ...  ...  ...         ...      ...
# Software Systems                   2.7  1.2  2.0  4.0     10366.7  13306.1
# Sustainable Energy                 2.0  NaN  2.0  2.0         0.0      NaN
# Sustainable Technology             2.0  NaN  2.0  2.0         0.0      NaN
# Systems Engineering                2.0  NaN  2.0  2.0         0.0      NaN
# Technology & Innovation            2.0  NaN  2.0  2.0     33800.0      NaN
#
#                                       Living_Cost_Index        ...  \
#                            min    max              mean   std  ...
# Program                                                        ...
# AI Engineering            6100   6100              72.3   NaN  ...
# Aerospace Engineering        0  52300              71.3   3.8  ...
# Applied Mathematics       3900   3900              56.8   NaN  ...
# Architecture              2800   3500              66.0   5.5  ...
# Artificial Intelligence      0  58000              63.1  15.6  ...
# ...                        ...    ...               ...   ...  ...
# Software Systems           500  25500              65.2   6.7  ...
# Sustainable Energy           0      0              71.2   NaN  ...
# Sustainable Technology       0      0              75.1   NaN  ...
# Systems Engineering          0      0              66.7   NaN  ...
# Technology & Innovation  33800  33800              82.0   NaN  ...
#
#                         Visa_Fee_USD      Insurance_USD                    \
#                                  min  max          mean    std  min   max
# Program
# AI Engineering                    90   90         800.0    NaN  800   800
# Aerospace Engineering            110  160        1200.0  424.3  900  1500
# Applied Mathematics              120  120         350.0    NaN  350   350
# Architecture                     120  160         475.0   35.4  450   500
# Artificial Intelligence           60  485         650.2  310.4  200  1500
# ...                              ...  ...           ...    ...  ...   ...
# Software Systems                  75  235         750.0  180.3  550   900
# Sustainable Energy               120  120         750.0    NaN  750   750
# Sustainable Technology           110  110         400.0    NaN  400   400
# Systems Engineering              275  275         700.0    NaN  700   700
# Technology & Innovation           90   90         800.0    NaN  800   800
#
#                         Exchange_Rate
#                                  mean     std     min      max
# Program
# AI Engineering                 1300.0     NaN  1300.0   1300.0
# Aerospace Engineering             1.0     0.1     0.9      1.0
# Applied Mathematics              95.5     NaN    95.5     95.5
# Architecture                      0.9     0.0     0.9      0.9
# Artificial Intelligence        1126.9  6130.7     0.3  42150.0
# ...                               ...     ...     ...      ...
# Software Systems                434.1   749.9     0.9   1300.0
# Sustainable Energy               10.4     NaN    10.4     10.4
# Sustainable Technology           10.4     NaN    10.4     10.4
# Systems Engineering              10.4     NaN    10.4     10.4
# Technology & Innovation           1.3     NaN     1.3      1.3
#
# [92 rows x 28 columns]
#
# Summary statistics by Level:
#          Duration_Years                Tuition_USD                      \
#                    mean  std  min  max        mean      std min    max
# Level
# Bachelor            3.5  0.5  3.0  5.0     19792.7  15534.6   0  57000
# Master              2.0  0.2  1.0  3.0     14522.0  16642.4   0  62000
# PhD                 4.1  0.3  3.0  5.0     17129.6  17438.8   0  56000
#
#          Living_Cost_Index        ... Visa_Fee_USD      Insurance_USD         \
#                       mean   std  ...          min  max          mean    std
# Level                             ...
# Bachelor              64.6  12.4  ...           40  490         717.2  318.0
# Master                64.7  14.5  ...           40  485         691.2  309.7
# PhD                   63.2  14.4  ...           60  485         693.4  353.7
#
#                     Exchange_Rate
#           min   max          mean     std  min      max
# Level
# Bachelor  200  1500         496.6  3356.2  0.3  42150.0
# Master    200  1500         608.5  3518.8  0.3  42150.0
# PhD       200  1500         896.2  5137.8  0.3  42150.0
#
# [3 rows x 28 columns]
#
# Key Metrics:
# Average TCA by country: Country
# USA           127748.5
# Hong Kong      96520.0
# Singapore      89517.8
# Australia      85741.3
# Canada         73643.6
#                 ...
# Ghana          12548.0
# Uzbekistan     12496.0
# Bangladesh      9216.0
# Algeria         8532.0
# Tunisia         7773.3
# Name: TCA, Length: 71, dtype: float64
# TCA range by program type:                              min       max     mean
# Program
# AI Engineering           21710.0   21710.0  21710.0
# Aerospace Engineering    28310.0  144860.0  86585.0
# Applied Mathematics      21520.0   21520.0  21520.0
# Architecture             33770.0   50560.0  42165.0
# Artificial Intelligence   6660.0  163260.0  41540.7
# ...                          ...       ...      ...
# Software Systems         17275.0   72535.0  36600.0
# Sustainable Energy       24420.0   24420.0  24420.0
# Sustainable Technology   29710.0   29710.0  29710.0
# Systems Engineering      20875.0   20875.0  20875.0
# Technology & Innovation  71490.0   71490.0  71490.0
#
# [92 rows x 3 columns]

# %% [markdown]
# Data Visualization Dashboard

# %%
# Create a dashboard using plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Interactive scatter plot
fig = px.scatter(df, x='TCA', y='Duration_Years', color='Country',
                 title='Cost vs Duration by Country',
                 hover_data=['Program'])
fig.show()

# Interactive box plot
fig = px.box(df, x='Country', y='TCA',
             title='Cost Distribution by Country')
fig.show()

# %%
print(df['TCA'].describe().round(1))
# Out:
# count       907.0
# mean      52218.1
# std       37459.2
# min        5700.0
# 25%       22644.5
# 50%       40020.0
# 75%       75600.0
# max      199860.0
# Name: TCA, dtype: float64

# %% [markdown]
# Total Cost of Attendance Visual Output

# %%
# Set the style for better visualization
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (15, 10)

# Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 15))
fig.suptitle('TCA Averages by Different Categories', fontsize=16, y=1.02)

# 1. TCA by Level
level_avg = df.groupby('Level')['TCA'].mean().sort_values(ascending=False)
sns.barplot(x=level_avg.index, y=level_avg.values, ax=axes[0, 0], palette='viridis')
axes[0, 0].set_title('Average TCA by Education Level')
axes[0, 0].set_xlabel('Education Level')
axes[0, 0].set_ylabel('Average TCA (USD)')
axes[0, 0].tick_params(axis='x', rotation=90)

# 2. TCA by Country (Top 30)
country_avg = df.groupby('Country')['TCA'].mean().sort_values(ascending=False).head(30)
sns.barplot(x=country_avg.index, y=country_avg.values, ax=axes[0, 1], palette='plasma')
axes[0, 1].set_title('Top 30 Countries by Average TCA')
axes[0, 1].set_xlabel('Country')
axes[0, 1].set_ylabel('Average TCA (USD)')
axes[0, 1].tick_params(axis='x', rotation=90)

# 3. TCA by City (Top 30)
city_avg = df.groupby('City')['TCA'].mean().sort_values(ascending=False).head(30)
sns.barplot(x=city_avg.index, y=city_avg.values, ax=axes[1, 0], palette='magma')
axes[1, 0].set_title('Top 30 Cities by Average TCA')
axes[1, 0].set_xlabel('City')
axes[1, 0].set_ylabel('Average TCA (USD)')
axes[1, 0].tick_params(axis='x', rotation=90)

# 4. TCA by Program (Top 30)
program_avg = df.groupby('Program')['TCA'].mean().sort_values(ascending=False).head(30)
sns.barplot(x=program_avg.index, y=program_avg.values, ax=axes[1, 1], palette='cividis')
axes[1, 1].set_title('Top 30 Programs by Average TCA')
axes[1, 1].set_xlabel('Program')
axes[1, 1].set_ylabel('Average TCA (USD)')
axes[1, 1].tick_params(axis='x', rotation=90)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Save the plot
plt.savefig('TCA_analysis.png', bbox_inches='tight', dpi=300)
plt.close()

# %%
# Print summary statistics
print("\nTCA Analysis Summary:")
print("\nAverage TCA by Level:")
print(level_avg.round(1))
print("\nTop 30 Countries by Average TCA:")
print(country_avg.round(1))
print("\nTop 30 Cities by Average TCA:")
print(city_avg.round(1))
print("\nTop 30 Programs by Average TCA:")
print(program_avg.round(1))
# Out:
# TCA Analysis Summary:
#
# Average TCA by Level:
# Level
# PhD         69115.4
# Bachelor    64526.5
# Master      38155.5
# Name: TCA, dtype: float64
#
# Top 30 Countries by Average TCA:
# Country
# USA               127748.5
# Hong Kong          96520.0
# Singapore          89517.8
# Australia          85741.3
# Canada             73643.6
# UK                 73049.0
# New Zealand        62987.2
# UAE                59182.5
# Ireland            58805.0
# Israel             57750.0
# Switzerland        53408.8
# Netherlands        45917.5
# Taiwan             40740.0
# France             36950.9
# Italy              36317.1
# Japan              36282.5
# Kuwait             35936.0
# Denmark            35621.3
# Belgium            34761.1
# Luxembourg         34557.1
# Czech Republic     34500.0
# Bahrain            33986.0
# Norway             33339.5
# Spain              32322.9
# Lebanon            31062.0
# Sweden             30838.0
# Iceland            30340.0
# Germany            30161.4
# Saudi Arabia       29971.0
# Austria            29143.3
# Name: TCA, dtype: float64
#
# Top 30 Cities by Average TCA:
# City
# Stanford            193385.0
# MIT                 189660.0
# Baltimore           163260.0
# New Haven           161460.0
# Princeton           156160.0
# Ithaca              153460.0
# Los Angeles         151460.0
# Ann Arbor           142310.0
# Atlanta             142035.0
# Seattle             141643.3
# Urbana-Champaign    137460.0
# San Diego           136660.0
# Nashville           133760.0
# Berkeley            130560.0
# Minneapolis         128210.0
# Boston              126820.0
# Philadelphia        125760.0
# Madison             125160.0
# New York            122093.3
# Cambridge           120627.5
# Austin              118100.0
# Urbana              114960.0
# San Francisco       114260.0
# Sydney              108640.9
# Tempe               107960.0
# Columbus            106160.0
# Chicago             105693.3
# Vancouver           102835.0
# Gainesville         101860.0
# Oxford              101061.2
# Name: TCA, dtype: float64
#
# Top 30 Programs by Average TCA:
# Program
# Machine Learning             157660.0
# Chemical Engineering         123860.0
# Psychology                   116635.0
# Digital Systems & AI         113190.0
# Computer Science & Design    106490.0
# Climate Science              100050.0
# Political Science             95135.0
# Pharmaceutical Sciences       92788.0
# Chemistry                     89926.0
# Economics                     87861.7
# Quantum Computing             87735.0
# Aerospace Engineering         86585.0
# Electrical Engineering        85956.7
# Finance                       83505.0
# Biomedical Sciences           75807.5
# Physics                       74663.9
# Environmental Computing       73930.0
# Data Science & AI             72590.0
# Computing & Innovation        71890.0
# Computer Science              71873.4
# Technology & Innovation       71490.0
# Business                      68315.0
# Biotechnology                 66283.8
# Engineering                   65671.1
# Mathematics                   64797.5
# Industrial Engineering        62890.0
# Business Informatics          62728.0
# Robotics                      57922.1
# Computing Systems             57385.0
# Business Analytics            56420.2
# Name: TCA, dtype: float64

# %% [markdown]
# Remove TCA outliers and export for modeling

# %%
# Detect outliers using IQR method

Q1 = df['TCA'].quantile(0.25)
Q3 = df['TCA'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
    
print(f"Initial number of rows: {len(df)}")


# Keep rows within TCA outliers
df_cleaned = df[(df['TCA'] >= lower_bound) & (df['TCA'] <= upper_bound)]

# Print final number of rows and number of rows removed
print(f"\nFinal number of rows: {len(df_cleaned)}")
print(f"Number of rows removed: {len(df) - len(df_cleaned)}")

# Remove columns used in TCA calculation to avoid overfitting in future models
columns_to_remove = ['Tuition_USD', 'Visa_Fee_USD', 'Rent_USD', 'Insurance_USD', 'Duration_Years']
df_cleaned = df_cleaned.drop(columns=columns_to_remove, errors='ignore')

# Export the cleaned dataset
data_dir = '../data'
output_file = os.path.join(data_dir, 'TCA_no_outliers.csv')
df_cleaned.to_csv(output_file, index=False)
print(f"\nCleaned dataset exported to: {output_file}")
# Out:
# Initial number of rows: 907
#
# Final number of rows: 889
# Number of rows removed: 18
#
# Cleaned dataset exported to: ../data\TCA_no_outliers.csv
#
# Cleaned dataset exported to: ../data\TCA_no_outliers.csv
